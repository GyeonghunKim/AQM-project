# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt

# %%
from worm_prop import *

# %%
epsilon_list = np.array([0.03, 0.02, 0.01, 0.008, 0.005, 0.002, 0.001])

# %%
lattice = Lattice(2, 2, 2)

# %%
simulation = WormAlgorithm(lattice=lattice, mu=1.4, beta=12, epsilon=epsilon_list[0])

# %%
n_list, e_list = simulation.run(10000)
# Out:
#   0%|          | 0/10000 [00:00<?, ?it/s]

# %%
plt.plot(simulation.n_list)

# %%
plt.plot(n_list)

# %%
plt.plot(e_list)

# %%
simulation.worm.show_worm()
# Out:
# (<Figure size 1800x400 with 1 Axes>, <Axes: >)

# %%
simulation.single_run()
fig, ax = simulation.grid_world.world_map()
ax.set_xlim([0, 100])

fig, ax = simulation.grid_world.world_map()
ax.set_xlim([simulation.time_length - 100, simulation.time_length])
# Out:
# (300.0, 400.0)

# %%
simulation.grid_world.world_map()
# Out:
# (<Figure size 1800x400 with 1 Axes>, <Axes: >)
